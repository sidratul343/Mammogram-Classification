# %% [markdown]
# # How To Use Google Colab
#
# Google Colaboratory which is called “Colab” in short provided by Google Research, especially well suited to team work, computer vision, machine learning, data analysis etc. If you have GPU memory allocation issue, google colab can be a better choice. Moreover, sometimes users faces prpblem in installing Anaconda, jupyter, keras sometimes, where you can directly dive into colab network and start working with python.
#
# All you have to do is, write google colab on any browser. This link might be helpful : https://colab.research.google.com/
#
# A page like this will be appeared:
#
# ![c-1.png](attachment:c-1.png)

# %% [markdown]
# There are a few options can be seen named File, Edit, View, Insert, Runtime, Tools and Help. By clicking on File option, a new notebook can be created, existing notebook can be opened, a notebook can be uploaded etc.
#
# ![C-2.png](attachment:C-2.png)

# %% [markdown]
# After clicking on new notebook, a new notebook will be opened.
#
# ![c-3.png](attachment:c-3.png)
#
# You can change the name from untitled.

# %% [markdown]
# by clicking on **Runtime**, GPU can be enabled.
#
# ![c-4.png](attachment:c-4.png)
#
# Here, you can see the option **change runtime type**.

# %% [markdown]
# Click **change runtime type**, you will see something like this.
#
# ![c-5.png](attachment:c-5.png)
#
# Under **Hardware accelerator** change the **None** type to **GPU** and click **Save**.

# %% [markdown]
# ![c-6.png](attachment:c-6.png)
#
# Now **GPU** is connected. You can check which **GPU** is provided by running this code.

# %%
! nvidia-smi

# %% [markdown]
# ![c-7.png](attachment:c-7.png)
#
# You can see the **GPU Configuration** here. Wr are given a **Tesla T4** GPU.

# %% [markdown]
# Next step is connecting google drive with colab. See the snapshots for step by step process.
#
# ![c-8.png](attachment:c-8.png)

# %% [markdown]
# ![c-9.png](attachment:c-9.png)

# %% [markdown]
# ![c10.png](attachment:c10.png)

# %% [markdown]
# If you see a cell like this, run the cell.
#
# ![c11.png](attachment:c11.png)

# %% [markdown]
# After connecting google drive, you will see something like this.
#
# ![c12.png](attachment:c12.png)

# %% [markdown]
# Look carefully!!
#
# **click Drive-->MyDrive-->Your desired folder/image-->copy path**
#
# ![c13.png](attachment:c13.png)
#
# Afterwards, you can use the directory on your code.
#
#
# ## Happy Learning!
